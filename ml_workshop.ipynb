# %%
'''A Perceptron is a simple linear classifier.It tries to find a linear decision boundary (a straight line in 2D) that separates the two classes.
   model2 = model.fit(x, y)   -This step trains the perceptron.It adjusts internal weights (w1, w2, and bias b) to classify the training samples correctly.
   After training, model2 (which is the same as model after training) stores:the weights it learned for each feature, and
   the bias term. output=w1 ​× x1 ​+ w2 ​× x2 ​+ b
   op=model2.predict([[14,12]])----
   The perceptron applies the formula using its learned weights and bias

# %%
#1. Training
#Load the DATA(our own data)
x=[[1,0],[11,14],[1,1],[2,3]]
y=['boy','girl','boy','girl']
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(x,y)
#2. Testing
op=model2.predict([[14,12]])
print(op)
# Out:
# ['girl']

# %%
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
print(file)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(x,y)
#2. Testing
op=model2.predict([[5,6,7,8]])
print(op)
# Out:
# ['virginica']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
print(op)
# Out:
# 90.0
# ['setosa' 'setosa' 'setosa' 'setosa' 'versicolor' 'versicolor' 'virginica'
#  'versicolor' 'setosa' 'versicolor' 'versicolor' 'versicolor' 'versicolor'
#  'versicolor' 'setosa' 'setosa' 'versicolor' 'setosa' 'versicolor'
#  'setosa' 'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'setosa']

# %%
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)
from sklearn.linear_model import Perceptron
model=Perceptron()
model2=model.fit(xtrain,ytrain)
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(op)
# Out:
# ['versicolor' 'setosa' 'versicolor' 'setosa' 'versicolor' 'versicolor'
#  'versicolor' 'versicolor' 'versicolor' 'versicolor' 'virginica'
#  'versicolor' 'versicolor' 'versicolor' 'versicolor' 'versicolor'
#  'versicolor' 'setosa' 'setosa' 'versicolor' 'versicolor' 'versicolor'
#  'virginica' 'versicolor' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'virginica' 'virginica']

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
#print(op)
# Out:
# 83.33333333333334

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
#print(op)
# Out:
# 83.33333333333334

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,op)
print(cm)
#print(op)
# Out:
# 83.33333333333334
# [[10  0  0]
#  [ 1  8  0]
#  [ 0  4  7]]

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
#print(op)
# Out:
# 83.33333333333334
# [[10  0  0]
#  [ 1  8  0]
#  [ 0  4  7]]

# %%
#printing classification report
from sklearn.metrics import classification_report
report=classification_report(ytest,op)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       0.91      1.00      0.95        10
#   versicolor       0.67      0.89      0.76         9
#    virginica       1.00      0.64      0.78        11
#
#     accuracy                           0.83        30
#    macro avg       0.86      0.84      0.83        30
# weighted avg       0.87      0.83      0.83        30

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/drive/MyDrive/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
#print(op)
# Out:
# 83.33333333333334
# [[10  0  0]
#  [ 1  8  0]
#  [ 0  4  7]]

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/drive/MyDrive/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']

#encode categorical labels into numerical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y_encoded=le.fit_transform(y)


from sklearn.model_selection import train_test_split
#during ytraining we will give encoded y
xtrain, xtest, ytrain, ytest=train_test_split(x,y_encoded,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
#print(op)
#predicting with a random value
op2=model.predict([[5,6,7,8]])
print(op2)
#for giving class inverse transform
print("predicted label:",le.inverse_transform(op2))
# Out:
# 83.33333333333334
# [[10  0  0]
#  [ 1  8  0]
#  [ 0  4  7]]
# [2]
# predicted label: ['virginica']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
#1. Training
#Load the DATA(scikit data)

from sklearn.datasets import load_iris
file=load_iris()
x=file.data #load features
y=file.target #load classes

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.linear_model import Perceptron
model=Perceptron()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
45
op2=model.predict([[5,6,7,8]])
print(op2)

#print(op)
# Out:
# 80.0
# [[10  0  0]
#  [ 6  3  0]
#  [ 0  0 11]]
# [2]

# %%
#1. Training
#Load the DATA(scikit data)

from sklearn.datasets import load_iris
file=load_iris()
x=file.data #load features
y=file.target #load classes

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
45
op2=model.predict([[5,6,7,8]])
print(op2)

#print(op)
# Out:
# 100.0
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# [2]

# %%
#1. Training
#Load the DATA(scikit data)

from sklearn.datasets import load_iris
file=load_iris()
x=file.data #load features
y=file.target #load classes

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.tree import DecisionTreeClassifier
#by default gini
model=DecisionTreeClassifier()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)
45
op2=model.predict([[5,6,7,8]])
print(op2)
print("decision tree graph\n")
from sklearn import tree
import graphviz
fn=file.feature_names
cn=file.target_names
dot_data=tree.export_graphviz(model2,
                              feature_names=fn,
                              class_names=cn,
                              filled=True,
                              rounded=True,
                              special_characters=True)
graph=graphviz.Source(dot_data)

graph

#print(op)
# Out:
# 100.0
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# [2]
# decision tree graph

# %%
#1. Training
#Load the DATA(scikit data)

from sklearn.datasets import load_iris
file=load_iris()
x=file.data #load features
y=file.target #load classes

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.tree import DecisionTreeClassifier
#by setting information gain
model=DecisionTreeClassifier(criterion="entropy")
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(ytest,op)
cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
print(cm)

op2=model.predict([[5,6,7,8]])
print(op2)
print("decision tree graph\n")
from sklearn import tree
import graphviz
fn=file.feature_names
cn=file.target_names
dot_data=tree.export_graphviz(model2,
                              feature_names=fn,
                              class_names=cn,
                              filled=True,
                              rounded=True,
                              special_characters=True)
graph=graphviz.Source(dot_data)

graph

#print(op)
# Out:
# 100.0
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# [2]
# decision tree graph

# %%
#1. Training
#Load the DATA(our own data)
import pandas as pd
file=pd.read_csv('/content/drive/MyDrive/irisexcel.csv')
x=file[['sepal_length','sepal_width','petal_length','petal_width']]
y=file['species']
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y,train_size=0.8,random_state=42)
#Load the MODEL
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
#Fit DATA into MODEL
model2=model.fit(xtrain,ytrain)
#2. Testing
op=model2.predict(xtest)
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,op)
print(score*100)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,op)
print(cm)
#print(op)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cmd=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model2.classes_)
cmd.plot()
# Out:
# 100.0
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
#load kmeans model
import pandas as pd

from sklearn.cluster import KMeans
model=KMeans(n_clusters=4,max_iter=3)
#load data
file=pd.read_csv('/content/drive/MyDrive/irisexcel.csv')
#we only need 2D feature set so we select this
x=file[['sepal_length','sepal_width']]
print(x)
#fitting
model2=model.fit(x)
centers=model2.cluster_centers_
labels=model2.labels_
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(file['sepal_length'],file['sepal_width'],c=labels,cmap="rainbow")

#

# %%
#linear regression
x=[[1],[2],[3],[4]]
y=[[1],[4],[9],[16]]
import matplotlib.pyplot as plt
plt.plot(x,y)
#load the model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
#fit the data
model2=model.fit(x,y)
ynew=model2.predict(x)
plt.plot(x,ynew)
op=model2.predict([[5]])
op
# Out:
# array([[20.]])
